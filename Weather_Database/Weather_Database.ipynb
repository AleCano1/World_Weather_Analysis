# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=285f8b6337684965e7a20ba115122f37

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description": city_weather_description})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 1 | mtinko
# Processing Record 3 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 4 of Set 1 | jamtara
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | port hardy
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 1 | lazaro cardenas
# Processing Record 15 of Set 1 | vestmanna
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | geraldton
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | touros
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | provideniya
# Processing Record 24 of Set 1 | severo-kurilsk
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | krasnouralsk
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | kieta
# Processing Record 35 of Set 1 | airai
# Processing Record 36 of Set 1 | tungor
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | norman wells
# Processing Record 39 of Set 1 | te anau
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | kahului
# Processing Record 42 of Set 1 | bolshaya rechka
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | anadyr
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | petlawad
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | mapiripan
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | bahia honda
# Processing Record 1 of Set 2 | husavik
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | visnes
# Processing Record 4 of Set 2 | faanui
# Processing Record 5 of Set 2 | westport
# Processing Record 6 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 7 of Set 2 | los llanos de aridane
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | cabrobo
# Processing Record 11 of Set 2 | alta floresta
# Processing Record 12 of Set 2 | awbari
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | buraydah
# Processing Record 15 of Set 2 | hofn
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | bathsheba
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | saint george
# Processing Record 21 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 2 | wattegama
# Processing Record 23 of Set 2 | jaguey grande
# Processing Record 24 of Set 2 | poum
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | victoria
# Processing Record 27 of Set 2 | poronaysk
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | garbolovo
# Processing Record 32 of Set 2 | upernavik
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | murchison
# Processing Record 35 of Set 2 | kaseda
# Processing Record 36 of Set 2 | baykit
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | puno
# Processing Record 40 of Set 2 | saldanha
# Processing Record 41 of Set 2 | lichuan
# Processing Record 42 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 43 of Set 2 | hay river
# Processing Record 44 of Set 2 | galesong
# Processing Record 45 of Set 2 | dunedin
# Processing Record 46 of Set 2 | terrace
# Processing Record 47 of Set 2 | kaoma
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | dublin
# Processing Record 50 of Set 2 | hermanus
# Processing Record 1 of Set 3 | leningradskiy
# Processing Record 2 of Set 3 | samarai
# Processing Record 3 of Set 3 | arandis
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | kissidougou
# Processing Record 6 of Set 3 | zhuzhou
# Processing Record 7 of Set 3 | port-gentil
# Processing Record 8 of Set 3 | winnemucca
# Processing Record 9 of Set 3 | havoysund
# Processing Record 10 of Set 3 | porto novo
# Processing Record 11 of Set 3 | roma
# Processing Record 12 of Set 3 | tual
# Processing Record 13 of Set 3 | surt
# Processing Record 14 of Set 3 | komsomolskiy
# Processing Record 15 of Set 3 | jiwani
# Processing Record 16 of Set 3 | alyangula
# Processing Record 17 of Set 3 | piedra gorda
# Processing Record 18 of Set 3 | galveston
# Processing Record 19 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 3 | praia
# Processing Record 21 of Set 3 | hasaki
# Processing Record 22 of Set 3 | jati
# Processing Record 23 of Set 3 | riyadh
# Processing Record 24 of Set 3 | athens
# Processing Record 25 of Set 3 | tahta
# Processing Record 26 of Set 3 | kamenka
# Processing Record 27 of Set 3 | magadan
# Processing Record 28 of Set 3 | bumba
# Processing Record 29 of Set 3 | magistralnyy
# Processing Record 30 of Set 3 | gemena
# Processing Record 31 of Set 3 | mont-de-marsan
# Processing Record 32 of Set 3 | cockburn town
# Processing Record 33 of Set 3 | guerrero negro
# Processing Record 34 of Set 3 | mokhotlong
# Processing Record 35 of Set 3 | talnakh
# Processing Record 36 of Set 3 | sofiysk
# City not found. Skipping...
# Processing Record 37 of Set 3 | shetpe
# Processing Record 38 of Set 3 | hanzhong
# Processing Record 39 of Set 3 | garowe
# Processing Record 40 of Set 3 | dudinka
# Processing Record 41 of Set 3 | sheridan
# Processing Record 42 of Set 3 | felipe carrillo puerto
# Processing Record 43 of Set 3 | anisoc
# Processing Record 44 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 3 | darnah
# Processing Record 46 of Set 3 | tuatapere
# Processing Record 47 of Set 3 | zhuhai
# Processing Record 48 of Set 3 | nemuro
# Processing Record 49 of Set 3 | heze
# Processing Record 50 of Set 3 | lasa
# Processing Record 1 of Set 4 | chokurdakh
# Processing Record 2 of Set 4 | yellowknife
# Processing Record 3 of Set 4 | bambous virieux
# Processing Record 4 of Set 4 | san patricio
# Processing Record 5 of Set 4 | dergachi
# Processing Record 6 of Set 4 | verkhnyachka
# Processing Record 7 of Set 4 | coquimbo
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | lagos
# Processing Record 10 of Set 4 | cabo san lucas
# Processing Record 11 of Set 4 | baishishan
# Processing Record 12 of Set 4 | ahipara
# Processing Record 13 of Set 4 | amberley
# Processing Record 14 of Set 4 | beian
# Processing Record 15 of Set 4 | haverfordwest
# Processing Record 16 of Set 4 | ribeira brava
# Processing Record 17 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 18 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 4 | harlingen
# Processing Record 20 of Set 4 | saint-philippe
# Processing Record 21 of Set 4 | terney
# Processing Record 22 of Set 4 | nikolskoye
# Processing Record 23 of Set 4 | sitka
# Processing Record 24 of Set 4 | georgetown
# Processing Record 25 of Set 4 | aketi
# Processing Record 26 of Set 4 | muros
# Processing Record 27 of Set 4 | biak
# Processing Record 28 of Set 4 | ribeira grande
# Processing Record 29 of Set 4 | constitucion
# Processing Record 30 of Set 4 | mount isa
# Processing Record 31 of Set 4 | itororo
# Processing Record 32 of Set 4 | lhokseumawe
# Processing Record 33 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | bethel
# Processing Record 35 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | pangnirtung
# Processing Record 37 of Set 4 | mokhsogollokh
# Processing Record 38 of Set 4 | caravelas
# Processing Record 39 of Set 4 | padang
# Processing Record 40 of Set 4 | marondera
# Processing Record 41 of Set 4 | salalah
# Processing Record 42 of Set 4 | elizabeth city
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | puerto escondido
# Processing Record 45 of Set 4 | ilulissat
# Processing Record 46 of Set 4 | mackay
# Processing Record 47 of Set 4 | pangody
# Processing Record 48 of Set 4 | rurrenabaque
# Processing Record 49 of Set 4 | harper
# Processing Record 50 of Set 4 | kidal
# Processing Record 1 of Set 5 | morden
# Processing Record 2 of Set 5 | isangel
# Processing Record 3 of Set 5 | santa clara
# Processing Record 4 of Set 5 | lata
# Processing Record 5 of Set 5 | bengkulu
# Processing Record 6 of Set 5 | popondetta
# Processing Record 7 of Set 5 | qaanaaq
# Processing Record 8 of Set 5 | red bluff
# Processing Record 9 of Set 5 | lompoc
# Processing Record 10 of Set 5 | wyndham
# Processing Record 11 of Set 5 | boa vista
# Processing Record 12 of Set 5 | east london
# Processing Record 13 of Set 5 | nantucket
# Processing Record 14 of Set 5 | cootamundra
# Processing Record 15 of Set 5 | ewa beach
# Processing Record 16 of Set 5 | barberton
# Processing Record 17 of Set 5 | alice town
# Processing Record 18 of Set 5 | narsaq
# Processing Record 19 of Set 5 | laguna
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | aksum
# Processing Record 22 of Set 5 | tiksi
# Processing Record 23 of Set 5 | takoradi
# Processing Record 24 of Set 5 | viedma
# Processing Record 25 of Set 5 | san isidro
# Processing Record 26 of Set 5 | kolding
# Processing Record 27 of Set 5 | gazanjyk
# Processing Record 28 of Set 5 | srednekolymsk
# Processing Record 29 of Set 5 | araguacu
# Processing Record 30 of Set 5 | mmathubudukwane
# Processing Record 31 of Set 5 | egvekinot
# Processing Record 32 of Set 5 | akureyri
# Processing Record 33 of Set 5 | bahia blanca
# Processing Record 34 of Set 5 | pyinmana
# Processing Record 35 of Set 5 | presidencia roque saenz pena
# Processing Record 36 of Set 5 | kamaishi
# Processing Record 37 of Set 5 | barra patuca
# Processing Record 38 of Set 5 | kenai
# Processing Record 39 of Set 5 | aalborg
# Processing Record 40 of Set 5 | gejiu
# Processing Record 41 of Set 5 | lagunas
# Processing Record 42 of Set 5 | lagoa
# Processing Record 43 of Set 5 | vila
# Processing Record 44 of Set 5 | asosa
# Processing Record 45 of Set 5 | slave lake
# Processing Record 46 of Set 5 | arraial do cabo
# Processing Record 47 of Set 5 | cidreira
# Processing Record 48 of Set 5 | algiers
# Processing Record 49 of Set 5 | esperance
# Processing Record 50 of Set 5 | bafoulabe
# Processing Record 1 of Set 6 | chisec
# Processing Record 2 of Set 6 | trairi
# Processing Record 3 of Set 6 | fortuna
# Processing Record 4 of Set 6 | puerto carreno
# Processing Record 5 of Set 6 | lima
# Processing Record 6 of Set 6 | zarate
# Processing Record 7 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 6 | pacific grove
# Processing Record 9 of Set 6 | san carlos
# Processing Record 10 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 6 | walvis bay
# Processing Record 12 of Set 6 | acapulco
# Processing Record 13 of Set 6 | lejanias
# Processing Record 14 of Set 6 | sarankhola
# Processing Record 15 of Set 6 | svetlaya
# Processing Record 16 of Set 6 | aklavik
# Processing Record 17 of Set 6 | nyurba
# Processing Record 18 of Set 6 | nishihara
# Processing Record 19 of Set 6 | souillac
# Processing Record 20 of Set 6 | inuvik
# Processing Record 21 of Set 6 | burlatskoye
# Processing Record 22 of Set 6 | maputo
# Processing Record 23 of Set 6 | kyzyl-suu
# Processing Record 24 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 6 | kurri kurri
# Processing Record 26 of Set 6 | asau
# Processing Record 27 of Set 6 | imeni zhelyabova
# Processing Record 28 of Set 6 | deniliquin
# Processing Record 29 of Set 6 | kachug
# Processing Record 30 of Set 6 | lichinga
# Processing Record 31 of Set 6 | tamiahua
# Processing Record 32 of Set 6 | santa fe
# Processing Record 33 of Set 6 | muyezerskiy
# Processing Record 34 of Set 6 | balabac
# Processing Record 35 of Set 6 | waiuku
# Processing Record 36 of Set 6 | sorong
# Processing Record 37 of Set 6 | paka
# Processing Record 38 of Set 6 | vesyegonsk
# Processing Record 39 of Set 6 | codrington
# Processing Record 40 of Set 6 | kaitangata
# Processing Record 41 of Set 6 | beaverlodge
# Processing Record 42 of Set 6 | bam
# Processing Record 43 of Set 6 | meulaboh
# Processing Record 44 of Set 6 | woodward
# Processing Record 45 of Set 6 | barnstaple
# Processing Record 46 of Set 6 | mitsamiouli
# Processing Record 47 of Set 6 | alice springs
# Processing Record 48 of Set 6 | grand gaube
# Processing Record 49 of Set 6 | adoni
# Processing Record 50 of Set 6 | champagnole
# Processing Record 1 of Set 7 | belinskiy
# Processing Record 2 of Set 7 | ballachulish
# Processing Record 3 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 7 | kijang
# Processing Record 5 of Set 7 | baculin
# Processing Record 6 of Set 7 | zhanaozen
# Processing Record 7 of Set 7 | port moresby
# Processing Record 8 of Set 7 | talara
# Processing Record 9 of Set 7 | vestmannaeyjar
# Processing Record 10 of Set 7 | xichang
# Processing Record 11 of Set 7 | nekrasovka
# Processing Record 12 of Set 7 | amazar
# Processing Record 13 of Set 7 | tabas
# Processing Record 14 of Set 7 | longonjo
# Processing Record 15 of Set 7 | oystese
# Processing Record 16 of Set 7 | nianzishan
# Processing Record 17 of Set 7 | benguela
# Processing Record 18 of Set 7 | oranjemund
# Processing Record 19 of Set 7 | port elizabeth
# Processing Record 20 of Set 7 | nome
# Processing Record 21 of Set 7 | cuamba
# Processing Record 22 of Set 7 | sisimiut
# Processing Record 23 of Set 7 | carutapera
# Processing Record 24 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 7 | auki
# Processing Record 26 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 7 | broken hill
# Processing Record 28 of Set 7 | beringovskiy
# Processing Record 29 of Set 7 | vardo
# Processing Record 30 of Set 7 | cornereva
# Processing Record 31 of Set 7 | aanekoski
# Processing Record 32 of Set 7 | barra do corda
# Processing Record 33 of Set 7 | minna
# Processing Record 34 of Set 7 | nelson
# Processing Record 35 of Set 7 | sola
# Processing Record 36 of Set 7 | port macquarie
# Processing Record 37 of Set 7 | jacmel
# Processing Record 38 of Set 7 | buta
# Processing Record 39 of Set 7 | sorland
# Processing Record 40 of Set 7 | huarmey
# Processing Record 41 of Set 7 | korla
# Processing Record 42 of Set 7 | puerto madero
# Processing Record 43 of Set 7 | nuristan
# Processing Record 44 of Set 7 | namwala
# Processing Record 45 of Set 7 | jasper
# Processing Record 46 of Set 7 | kathmandu
# Processing Record 47 of Set 7 | encheng
# Processing Record 48 of Set 7 | tarimoro
# Processing Record 49 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 7 | zemio
# Processing Record 1 of Set 8 | burriana
# Processing Record 2 of Set 8 | morganton
# Processing Record 3 of Set 8 | sur
# Processing Record 4 of Set 8 | arequipa
# Processing Record 5 of Set 8 | diu
# Processing Record 6 of Set 8 | novokizhinginsk
# Processing Record 7 of Set 8 | portland
# Processing Record 8 of Set 8 | vilhena
# Processing Record 9 of Set 8 | mamallapuram
# Processing Record 10 of Set 8 | agua branca
# Processing Record 11 of Set 8 | la ronge
# Processing Record 12 of Set 8 | cap malheureux
# Processing Record 13 of Set 8 | tsuruoka
# Processing Record 14 of Set 8 | ixtapa
# Processing Record 15 of Set 8 | kuruman
# Processing Record 16 of Set 8 | alofi
# Processing Record 17 of Set 8 | lavrentiya
# Processing Record 18 of Set 8 | agadir
# Processing Record 19 of Set 8 | tucurui
# Processing Record 20 of Set 8 | dingle
# Processing Record 21 of Set 8 | vila velha
# Processing Record 22 of Set 8 | vila franca do campo
# Processing Record 23 of Set 8 | wawa
# Processing Record 24 of Set 8 | sherlovaya gora
# Processing Record 25 of Set 8 | ust-nera
# Processing Record 26 of Set 8 | goderich
# Processing Record 27 of Set 8 | katsuura
# Processing Record 28 of Set 8 | wamba
# Processing Record 29 of Set 8 | santiago del estero
# Processing Record 30 of Set 8 | stokmarknes
# Processing Record 31 of Set 8 | maniitsoq
# Processing Record 32 of Set 8 | pasighat
# Processing Record 33 of Set 8 | olinda
# Processing Record 34 of Set 8 | yuanli
# Processing Record 35 of Set 8 | santa cruz
# Processing Record 36 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 8 | gogrial
# Processing Record 38 of Set 8 | port blair
# Processing Record 39 of Set 8 | bosobolo
# Processing Record 40 of Set 8 | tatarastii de sus
# City not found. Skipping...
# Processing Record 41 of Set 8 | wangou
# Processing Record 42 of Set 8 | bilibino
# Processing Record 43 of Set 8 | lakes entrance
# Processing Record 44 of Set 8 | urumqi
# Processing Record 45 of Set 8 | kuryk
# Processing Record 46 of Set 8 | kytlym
# City not found. Skipping...
# Processing Record 47 of Set 8 | lashio
# Processing Record 48 of Set 8 | dali
# Processing Record 49 of Set 8 | sainte-maxime
# Processing Record 50 of Set 8 | severnyy
# Processing Record 1 of Set 9 | beloha
# Processing Record 2 of Set 9 | ahumada
# City not found. Skipping...
# Processing Record 3 of Set 9 | moultonborough
# Processing Record 4 of Set 9 | hami
# Processing Record 5 of Set 9 | moshi
# Processing Record 6 of Set 9 | feldkirchen
# Processing Record 7 of Set 9 | kisangani
# Processing Record 8 of Set 9 | batemans bay
# Processing Record 9 of Set 9 | sambava
# Processing Record 10 of Set 9 | ostrovnoy
# Processing Record 11 of Set 9 | karratha
# Processing Record 12 of Set 9 | quijingue
# Processing Record 13 of Set 9 | nokha
# Processing Record 14 of Set 9 | merritt island
# Processing Record 15 of Set 9 | dekar
# Processing Record 16 of Set 9 | rongcheng
# Processing Record 17 of Set 9 | kuzhithurai
# Processing Record 18 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 9 | fairbanks
# Processing Record 20 of Set 9 | pandan
# Processing Record 21 of Set 9 | yerbogachen
# Processing Record 22 of Set 9 | zimmi
# Processing Record 23 of Set 9 | rio bueno
# Processing Record 24 of Set 9 | saint-pierre
# Processing Record 25 of Set 9 | springdale
# Processing Record 26 of Set 9 | uthal
# Processing Record 27 of Set 9 | pozo colorado
# Processing Record 28 of Set 9 | ullapool
# Processing Record 29 of Set 9 | havre-saint-pierre
# Processing Record 30 of Set 9 | luderitz
# Processing Record 31 of Set 9 | hualmay
# Processing Record 32 of Set 9 | kalmunai
# Processing Record 33 of Set 9 | metro
# Processing Record 34 of Set 9 | shenjiamen
# Processing Record 35 of Set 9 | byron bay
# Processing Record 36 of Set 9 | mouila
# Processing Record 37 of Set 9 | wodonga
# Processing Record 38 of Set 9 | tazovskiy
# Processing Record 39 of Set 9 | insar
# Processing Record 40 of Set 9 | buchanan
# Processing Record 41 of Set 9 | imbituba
# Processing Record 42 of Set 9 | yasnyy
# Processing Record 43 of Set 9 | bilma
# Processing Record 44 of Set 9 | athol
# Processing Record 45 of Set 9 | prince rupert
# Processing Record 46 of Set 9 | tilichiki
# Processing Record 47 of Set 9 | rio branco
# Processing Record 48 of Set 9 | taksimo
# Processing Record 49 of Set 9 | birobidzhan
# Processing Record 50 of Set 9 | mogadishu
# Processing Record 1 of Set 10 | derzhavinsk
# Processing Record 2 of Set 10 | salamanca
# Processing Record 3 of Set 10 | hamilton
# Processing Record 4 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 10 | san rafael
# Processing Record 6 of Set 10 | aleksandrovskiy zavod
# Processing Record 7 of Set 10 | omsukchan
# Processing Record 8 of Set 10 | ponta do sol
# Processing Record 9 of Set 10 | arlit
# Processing Record 10 of Set 10 | port keats
# Processing Record 11 of Set 10 | lekoni
# Processing Record 12 of Set 10 | bossangoa
# Processing Record 13 of Set 10 | innoshima
# Processing Record 14 of Set 10 | broome
# Processing Record 15 of Set 10 | sobolevo
# Processing Record 16 of Set 10 | guder
# Processing Record 17 of Set 10 | lebedyn
# Processing Record 18 of Set 10 | bracebridge
# Processing Record 19 of Set 10 | urzhum
# Processing Record 20 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 10 | yulara
# Processing Record 22 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 10 | lorengau
# Processing Record 24 of Set 10 | miesbach
# Processing Record 25 of Set 10 | chapais
# Processing Record 26 of Set 10 | naze
# Processing Record 27 of Set 10 | acarau
# Processing Record 28 of Set 10 | kongoussi
# Processing Record 29 of Set 10 | leshukonskoye
# Processing Record 30 of Set 10 | zhangjiakou
# Processing Record 31 of Set 10 | nouadhibou
# Processing Record 32 of Set 10 | kronshtadt
# Processing Record 33 of Set 10 | veraval
# Processing Record 34 of Set 10 | kigali
# Processing Record 35 of Set 10 | sept-iles
# Processing Record 36 of Set 10 | simplicio mendes
# Processing Record 37 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 10 | sibolga
# Processing Record 39 of Set 10 | bundaberg
# Processing Record 40 of Set 10 | abalak
# Processing Record 41 of Set 10 | iqaluit
# Processing Record 42 of Set 10 | umm bab
# Processing Record 43 of Set 10 | kurayoshi
# Processing Record 44 of Set 10 | challapata
# Processing Record 45 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 46 of Set 10 | pitimbu
# Processing Record 47 of Set 10 | gigmoto
# Processing Record 48 of Set 10 | aykhal
# Processing Record 49 of Set 10 | dzaoudzi
# Processing Record 50 of Set 10 | sovetskaya gavan
# Processing Record 1 of Set 11 | tynda
# Processing Record 2 of Set 11 | olafsvik
# Processing Record 3 of Set 11 | kinkala
# Processing Record 4 of Set 11 | salta
# Processing Record 5 of Set 11 | vanavara
# Processing Record 6 of Set 11 | henties bay
# Processing Record 7 of Set 11 | muttupet
# Processing Record 8 of Set 11 | itaituba
# Processing Record 9 of Set 11 | guarapari
# Processing Record 10 of Set 11 | ozernovskiy
# Processing Record 11 of Set 11 | olga
# Processing Record 12 of Set 11 | chico
# Processing Record 13 of Set 11 | price
# Processing Record 14 of Set 11 | basco
# Processing Record 15 of Set 11 | namatanai
# Processing Record 16 of Set 11 | shubarkuduk
# Processing Record 17 of Set 11 | monrovia
# Processing Record 18 of Set 11 | nelson bay
# Processing Record 19 of Set 11 | dongsheng
# Processing Record 20 of Set 11 | mongo
# Processing Record 21 of Set 11 | moerai
# Processing Record 22 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 11 | bandarbeyla
# Processing Record 24 of Set 11 | talaya
# Processing Record 25 of Set 11 | chalmette
# Processing Record 26 of Set 11 | sabang
# Processing Record 27 of Set 11 | barcelos
# Processing Record 28 of Set 11 | ovalle
# Processing Record 29 of Set 11 | sao miguel do araguaia
# Processing Record 30 of Set 11 | karaton
# Processing Record 31 of Set 11 | banda aceh
# Processing Record 32 of Set 11 | usinsk
# Processing Record 33 of Set 11 | kulob
# Processing Record 34 of Set 11 | sapele
# Processing Record 35 of Set 11 | kruisfontein
# Processing Record 36 of Set 11 | oskarshamn
# Processing Record 37 of Set 11 | kungurtug
# Processing Record 38 of Set 11 | lircay
# Processing Record 39 of Set 11 | half moon bay
# Processing Record 40 of Set 11 | la paz
# Processing Record 41 of Set 11 | baherden
# Processing Record 42 of Set 11 | bagahanglad
# City not found. Skipping...
# Processing Record 43 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 44 of Set 11 | mossendjo
# Processing Record 45 of Set 11 | kidodi
# Processing Record 46 of Set 11 | bubaque
# Processing Record 47 of Set 11 | rocha
# Processing Record 48 of Set 11 | pekan
# Processing Record 49 of Set 11 | hervey bay
# Processing Record 50 of Set 11 | kashi
# Processing Record 1 of Set 12 | flagstaff
# Processing Record 2 of Set 12 | sopiste
# City not found. Skipping...
# Processing Record 3 of Set 12 | road town
# Processing Record 4 of Set 12 | gisenyi
# Processing Record 5 of Set 12 | vuktyl
# Processing Record 6 of Set 12 | port augusta
# Processing Record 7 of Set 12 | nisia floresta
# Processing Record 8 of Set 12 | ukiah
# Processing Record 9 of Set 12 | bollnas
# Processing Record 10 of Set 12 | north fort myers
# Processing Record 11 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 12 | cayenne
# Processing Record 13 of Set 12 | coihaique
# Processing Record 14 of Set 12 | qandala
# Processing Record 15 of Set 12 | namibe
# Processing Record 16 of Set 12 | beyneu
# Processing Record 17 of Set 12 | manokwari
# Processing Record 18 of Set 12 | port lincoln
# Processing Record 19 of Set 12 | weligama
# Processing Record 20 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 21 of Set 12 | minab
# Processing Record 22 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 12 | benghazi
# Processing Record 24 of Set 12 | maun
# Processing Record 25 of Set 12 | moranbah
# Processing Record 26 of Set 12 | luangwa
# Processing Record 27 of Set 12 | rio grande
# Processing Record 28 of Set 12 | tatawin
# Processing Record 29 of Set 12 | zaraza
# Processing Record 30 of Set 12 | malatya
# Processing Record 31 of Set 12 | torbay
# Processing Record 32 of Set 12 | goma
# Processing Record 33 of Set 12 | lethem
# Processing Record 34 of Set 12 | waingapu
# Processing Record 35 of Set 12 | jiexiu
# Processing Record 36 of Set 12 | bukama
# Processing Record 37 of Set 12 | athabasca
# Processing Record 38 of Set 12 | lima duarte
# Processing Record 39 of Set 12 | kharp
# Processing Record 40 of Set 12 | huntsville
# Processing Record 41 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 42 of Set 12 | sokolo
# Processing Record 43 of Set 12 | saint anthony
# Processing Record 44 of Set 12 | straumen
# Processing Record 45 of Set 12 | mujiayingzi
# Processing Record 46 of Set 12 | kipini
# Processing Record 47 of Set 12 | lerwick
# Processing Record 48 of Set 12 | rakitnoye
# Processing Record 49 of Set 12 | vostok
# Processing Record 50 of Set 12 | yenagoa
# Processing Record 1 of Set 13 | avera
# Processing Record 2 of Set 13 | barra
# Processing Record 3 of Set 13 | oktyabrskoye
# Processing Record 4 of Set 13 | freeport
# Processing Record 5 of Set 13 | la rioja
# Processing Record 6 of Set 13 | tadine
# Processing Record 7 of Set 13 | fereydunshahr
# Processing Record 8 of Set 13 | zhigansk
# Processing Record 9 of Set 13 | kurilsk
# Processing Record 10 of Set 13 | havelock
# Processing Record 11 of Set 13 | sioux lookout
# Processing Record 12 of Set 13 | westerland
# Processing Record 13 of Set 13 | altamira
# Processing Record 14 of Set 13 | obo
# Processing Record 15 of Set 13 | cascais
# Processing Record 16 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 13 | bulgan
# Processing Record 18 of Set 13 | artyom
# Processing Record 19 of Set 13 | bambanglipuro
# Processing Record 20 of Set 13 | jurm
# Processing Record 21 of Set 13 | san juan
# Processing Record 22 of Set 13 | whitehorse
# Processing Record 23 of Set 13 | omboue
# Processing Record 24 of Set 13 | cape canaveral
# Processing Record 25 of Set 13 | mayumba
# Processing Record 26 of Set 13 | pampa
# Processing Record 27 of Set 13 | buala
# Processing Record 28 of Set 13 | zharkent
# Processing Record 29 of Set 13 | chulman
# Processing Record 30 of Set 13 | santa vitoria do palmar
# Processing Record 31 of Set 13 | palmer
# Processing Record 32 of Set 13 | carolina
# Processing Record 33 of Set 13 | okhotsk
# Processing Record 34 of Set 13 | smidovich
# Processing Record 35 of Set 13 | coruripe
# Processing Record 36 of Set 13 | grenville
# Processing Record 37 of Set 13 | bassano
# Processing Record 38 of Set 13 | mao
# Processing Record 39 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 13 | faya
# Processing Record 41 of Set 13 | smithers
# Processing Record 42 of Set 13 | belle glade
# Processing Record 43 of Set 13 | la gomera
# Processing Record 44 of Set 13 | dillon
# Processing Record 45 of Set 13 | stefan cel mare
# Processing Record 46 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 13 | ongandjera
# Processing Record 48 of Set 13 | oksfjord
# Processing Record 49 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 50 of Set 13 | macaubas
# Processing Record 1 of Set 14 | lautaro
# Processing Record 2 of Set 14 | korgen
# Processing Record 3 of Set 14 | gumushane
# City not found. Skipping...
# Processing Record 4 of Set 14 | vakhrushev
# Processing Record 5 of Set 14 | trincomalee
# Processing Record 6 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 7 of Set 14 | balkhash
# Processing Record 8 of Set 14 | barkly west
# Processing Record 9 of Set 14 | manggar
# Processing Record 10 of Set 14 | ayan
# Processing Record 11 of Set 14 | ende
# Processing Record 12 of Set 14 | stillwater
# Processing Record 13 of Set 14 | gilgit
# Processing Record 14 of Set 14 | klaksvik
# Processing Record 15 of Set 14 | maple creek
# Processing Record 16 of Set 14 | boromo
# Processing Record 17 of Set 14 | zinder
# Processing Record 18 of Set 14 | kandrian
# Processing Record 19 of Set 14 | baturaja
# Processing Record 20 of Set 14 | yizheng
# Processing Record 21 of Set 14 | yanam
# Processing Record 22 of Set 14 | haines junction
# Processing Record 23 of Set 14 | mersing
# Processing Record 24 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 25 of Set 14 | saint-georges
# Processing Record 26 of Set 14 | ankang
# Processing Record 27 of Set 14 | north charleston
# Processing Record 28 of Set 14 | svetlyy
# Processing Record 29 of Set 14 | wajima
# Processing Record 30 of Set 14 | krasnoselkup
# Processing Record 31 of Set 14 | college
# Processing Record 32 of Set 14 | santa rosa
# Processing Record 33 of Set 14 | mocuba
# Processing Record 34 of Set 14 | abu zabad
# Processing Record 35 of Set 14 | altoona
# Processing Record 36 of Set 14 | lugo
# Processing Record 37 of Set 14 | marshall
# Processing Record 38 of Set 14 | svobodnyy
# Processing Record 39 of Set 14 | santa cruz del sur
# Processing Record 40 of Set 14 | duluth
# Processing Record 41 of Set 14 | mpanda
# Processing Record 42 of Set 14 | susanville
# Processing Record 43 of Set 14 | lengshuitan
# Processing Record 44 of Set 14 | ustka
# Processing Record 45 of Set 14 | kiruna
# Processing Record 46 of Set 14 | chambas
# Processing Record 47 of Set 14 | comodoro rivadavia
# Processing Record 48 of Set 14 | jiayuguan
# Processing Record 49 of Set 14 | hobyo
# Processing Record 50 of Set 14 | paranapanema
# Processing Record 1 of Set 15 | buckeye
# Processing Record 2 of Set 15 | taltal
# Processing Record 3 of Set 15 | kailua
# Processing Record 4 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 5 of Set 15 | juegang
# Processing Record 6 of Set 15 | khorinsk
# Processing Record 7 of Set 15 | gazli
# Processing Record 8 of Set 15 | mountain home
# Processing Record 9 of Set 15 | gizo
# Processing Record 10 of Set 15 | lephepe
# City not found. Skipping...
# Processing Record 11 of Set 15 | charleville-mezieres
# Processing Record 12 of Set 15 | santa isabel
# Processing Record 13 of Set 15 | yelizovo
# Processing Record 14 of Set 15 | talcahuano
# Processing Record 15 of Set 15 | quatre cocos
# Processing Record 16 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 15 | clyde river
# Processing Record 18 of Set 15 | polis
# Processing Record 19 of Set 15 | kutum
# Processing Record 20 of Set 15 | maceio
# Processing Record 21 of Set 15 | tombouctou
# Processing Record 22 of Set 15 | pemangkat
# Processing Record 23 of Set 15 | gat
# Processing Record 24 of Set 15 | black river
# Processing Record 25 of Set 15 | shangrao
# Processing Record 26 of Set 15 | davila
# Processing Record 27 of Set 15 | tsumeb
# Processing Record 28 of Set 15 | chiang kham
# Processing Record 29 of Set 15 | khromtau
# Processing Record 30 of Set 15 | casambalangan
# Processing Record 31 of Set 15 | grindavik
# Processing Record 32 of Set 15 | mwinilunga
# Processing Record 33 of Set 15 | richards bay
# Processing Record 34 of Set 15 | ammapettai
# Processing Record 35 of Set 15 | kayankulam
# Processing Record 36 of Set 15 | amapa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 685

# %%
#Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mtinko      TZ  -4.5500   34.8500     59.32        98         100
# 1       Jamtara      IN  23.9500   86.8000     58.19        86           1
# 2          Lebu      CL -37.6167  -73.6500     64.24        75           1
# 3       Ushuaia      AR -54.8000  -68.3000     55.02        41          33
# 4  Longyearbyen      SJ  78.2186   15.6401     15.64        67           0
# 5    Port Hardy      CA  50.6996 -127.4199     45.75        95         100
# 6       Rikitea      PF -23.1203 -134.9692     78.46        71           9
# 7   New Norfolk      AU -42.7826  147.0587     57.92        75          49
# 8        Hobart      AU -42.8794  147.3294     58.26        86          75
# 9        Albany      US  42.6001  -73.9662     26.91        87         100
#
#    Wind Speed Current Description
# 0        4.92     overcast clouds
# 1        9.31           clear sky
# 2       17.47           clear sky
# 3        2.42    scattered clouds
# 4       20.71           clear sky
# 5       10.25       moderate rain
# 6       10.63           clear sky
# 7        1.79    scattered clouds
# 8        5.75       broken clouds
# 9        1.99          light snow

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
